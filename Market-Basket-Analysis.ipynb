# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori

# %%
df = pd.read_csv("OnlineRetail.csv", encoding='latin-1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.dropna(inplace=True)

# %%
df = df[df['Quantity'] > 0]

# %%
df.drop_duplicates(inplace=True)

# %%
basket = (df.groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().fillna(0))

basket.head()
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
#
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536365                      0.0                           0.0
# 536366                      0.0                           0.0
# 536367                      0.0                           0.0
# 536368                      0.0                           0.0
# 536369                      0.0                           0.0
#
# Description   I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                0.0                       0.0
# 536366                                0.0                       0.0
# 536367                                0.0                       0.0
# 536368                                0.0                       0.0
# 536369                                0.0                       0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                               0.0                       0.0
# 536366                               0.0                       0.0
# 536367                               0.0                       0.0
# 536368                               0.0                       0.0
# 536369                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                    0.0                      0.0  ...
# 536366                                    0.0                      0.0  ...
# 536367                                    0.0                      0.0  ...
# 536368                                    0.0                      0.0  ...
# 536369                                    0.0                      0.0  ...
#
# Description  ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536365                                    0.0                             0.0
# 536366                                    0.0                             0.0
# 536367                                    0.0                             0.0
# 536368                                    0.0                             0.0
# 536369                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536365                                   0.0                              0.0
# 536366                                   0.0                              0.0
# 536367                                   0.0                              0.0
# 536368                                   0.0                              0.0
# 536369                                   0.0                              0.0
#
# Description  ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# InvoiceNo
# 536365                                  0.0                               0.0
# 536366                                  0.0                               0.0
# 536367                                  0.0                               0.0
# 536368                                  0.0                               0.0
# 536369                                  0.0                               0.0
#
# Description  ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# InvoiceNo
# 536365                               0.0                               0.0
# 536366                               0.0                               0.0
# 536367                               0.0                               0.0
# 536368                               0.0                               0.0
# 536369                               0.0                               0.0
#
# [5 rows x 3877 columns]

# %%
basket = (basket > 0)

# %%
frequent_items = apriori(basket, min_support=0.02, use_colnames=True)
frequent_items.head()
# Out:
#     support                           itemsets
# 0  0.021688         (3 STRIPEY MICE FELTCRAFT)
# 1  0.039167           (6 RIBBONS RUSTIC CHARM)
# 2  0.025140  (60 CAKE CASES VINTAGE CHRISTMAS)
# 3  0.035445      (60 TEATIME FAIRY CAKE CASES)
# 4  0.027028   (72 SWEETHEART FAIRY CAKE CASES)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_items, metric="lift", min_threshold=1)
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0   (ALARM CLOCK BAKELIKE RED )  (ALARM CLOCK BAKELIKE GREEN)
# 1  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE RED )
# 2   (ALARM CLOCK BAKELIKE RED )   (ALARM CLOCK BAKELIKE PINK)
# 3   (ALARM CLOCK BAKELIKE PINK)   (ALARM CLOCK BAKELIKE RED )
# 4         (SPACEBOY LUNCH BOX )        (DOLLY GIRL LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.047313            0.042566  0.028593    0.604333  14.197612
# 1            0.042566            0.047313  0.028593    0.671736  14.197612
# 2            0.047313            0.033071  0.021364    0.451539  13.653725
# 3            0.033071            0.047313  0.021364    0.646003  13.653725
# 4            0.037980            0.033233  0.022874    0.602273  18.122934
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.026579    2.419798       0.975731  0.466549   0.586742
# 1               1.0  0.026579    2.902200       0.970892  0.466549   0.655434
# 2               1.0  0.019799    1.762987       0.972786  0.361974   0.432781
# 3               1.0  0.019799    2.691230       0.958457  0.361974   0.628423
# 4               1.0  0.021612    2.430729       0.982122  0.473214   0.588601
#
#    kulczynski
# 0    0.638035
# 1    0.638035
# 2    0.548771
# 3    0.548771
# 4    0.645292

# %%
strong_rules = rules[(rules['lift'] > 1.5) & (rules['confidence'] > 0.5)]
strong_rules
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE RED )
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 3                         (ALARM CLOCK BAKELIKE PINK)
# 4                               (SPACEBOY LUNCH BOX )
# 5                              (DOLLY GIRL LUNCH BOX)
# 6                (GARDENERS KNEELING PAD CUP OF TEA )
# 7                 (GARDENERS KNEELING PAD KEEP CALM )
# 8                    (PINK REGENCY TEACUP AND SAUCER)
# 9                   (GREEN REGENCY TEACUP AND SAUCER)
# 10                  (GREEN REGENCY TEACUP AND SAUCER)
# 12                 (ROSES REGENCY TEACUP AND SAUCER )
# 13                  (GREEN REGENCY TEACUP AND SAUCER)
# 14                            (HEART OF WICKER LARGE)
# 16                          (JUMBO BAG PINK POLKADOT)
# 19                             (JUMBO BAG STRAWBERRY)
# 21                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 22                           (JUMBO STORAGE BAG SUKI)
# 47                          (LUNCH BAG PINK POLKADOT)
# 51                           (LUNCH BAG SUKI DESIGN )
# 53                               (LUNCH BAG WOODLAND)
# 59                (PAPER CHAIN KIT VINTAGE CHRISTMAS)
# 62                   (PINK REGENCY TEACUP AND SAUCER)
# 63                 (ROSES REGENCY TEACUP AND SAUCER )
# 65                 (RED HANGING HEART T-LIGHT HOLDER)
# 66                 (ROSES REGENCY TEACUP AND SAUCER )
# 68                (WOODEN PICTURE FRAME WHITE FINISH)
# 69                      (WOODEN FRAME ANTIQUE WHITE )
# 70  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# 71  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 72  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...
# 73                   (PINK REGENCY TEACUP AND SAUCER)
# 75                  (GREEN REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)            0.047313
# 1                         (ALARM CLOCK BAKELIKE RED )            0.042566
# 3                         (ALARM CLOCK BAKELIKE RED )            0.033071
# 4                              (DOLLY GIRL LUNCH BOX)            0.037980
# 5                               (SPACEBOY LUNCH BOX )            0.033233
# 6                 (GARDENERS KNEELING PAD KEEP CALM )            0.034258
# 7                (GARDENERS KNEELING PAD CUP OF TEA )            0.040785
# 8                   (GREEN REGENCY TEACUP AND SAUCER)            0.029996
# 9                    (PINK REGENCY TEACUP AND SAUCER)            0.037279
# 10                         (REGENCY CAKESTAND 3 TIER)            0.037279
# 12                  (GREEN REGENCY TEACUP AND SAUCER)            0.042242
# 13                 (ROSES REGENCY TEACUP AND SAUCER )            0.037279
# 14                            (HEART OF WICKER SMALL)            0.043213
# 16                          (JUMBO BAG RED RETROSPOT)            0.046990
# 19                          (JUMBO BAG RED RETROSPOT)            0.035283
# 21                          (JUMBO BAG RED RETROSPOT)            0.042620
# 22                          (JUMBO BAG RED RETROSPOT)            0.041757
# 47                          (LUNCH BAG RED RETROSPOT)            0.050227
# 51                          (LUNCH BAG RED RETROSPOT)            0.048500
# 53                          (LUNCH BAG RED RETROSPOT)            0.044238
# 59                  (PAPER CHAIN KIT 50'S CHRISTMAS )            0.037603
# 62                 (ROSES REGENCY TEACUP AND SAUCER )            0.029996
# 63                   (PINK REGENCY TEACUP AND SAUCER)            0.042242
# 65               (WHITE HANGING HEART T-LIGHT HOLDER)            0.036631
# 66                         (REGENCY CAKESTAND 3 TIER)            0.042242
# 68                      (WOODEN FRAME ANTIQUE WHITE )            0.047259
# 69                (WOODEN PICTURE FRAME WHITE FINISH)            0.043753
# 70                  (GREEN REGENCY TEACUP AND SAUCER)            0.023522
# 71                 (ROSES REGENCY TEACUP AND SAUCER )            0.024817
# 72                   (PINK REGENCY TEACUP AND SAUCER)            0.029186
# 73  (ROSES REGENCY TEACUP AND SAUCER , GREEN REGEN...            0.029996
# 75  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...            0.037279
#
#     consequent support   support  confidence       lift  representativity  \
# 0             0.042566  0.028593    0.604333  14.197612               1.0
# 1             0.047313  0.028593    0.671736  14.197612               1.0
# 3             0.047313  0.021364    0.646003  13.653725               1.0
# 4             0.033233  0.022874    0.602273  18.122934               1.0
# 5             0.037980  0.022874    0.688312  18.122934               1.0
# 6             0.040785  0.024978    0.729134  17.877282               1.0
# 7             0.034258  0.024978    0.612434  17.877282               1.0
# 8             0.037279  0.024817    0.827338  22.193256               1.0
# 9             0.029996  0.024817    0.665702  22.193256               1.0
# 10            0.091929  0.020177    0.541245   5.887623               1.0
# 12            0.037279  0.029186    0.690932  18.534184               1.0
# 13            0.042242  0.029186    0.782923  18.534184               1.0
# 14            0.051845  0.021957    0.508115   9.800642               1.0
# 16            0.086319  0.029456    0.626866   7.262239               1.0
# 19            0.086319  0.022335    0.633028   7.333624               1.0
# 21            0.086319  0.021364    0.501266   5.807165               1.0
# 22            0.086319  0.023414    0.560724   6.495982               1.0
# 47            0.069486  0.028215    0.561762   8.084481               1.0
# 51            0.069486  0.024277    0.500556   7.203656               1.0
# 53            0.069486  0.023360    0.528049   7.599311               1.0
# 59            0.052870  0.024331    0.647059  12.238655               1.0
# 62            0.042242  0.023522    0.784173  18.563760               1.0
# 63            0.029996  0.023522    0.556833  18.563760               1.0
# 65            0.106334  0.024547    0.670103   6.301893               1.0
# 66            0.091929  0.022659    0.536398   5.834907               1.0
# 68            0.043753  0.025248    0.534247  12.210597               1.0
# 69            0.047259  0.025248    0.577065  12.210597               1.0
# 70            0.037279  0.021040    0.894495  23.994742               1.0
# 71            0.042242  0.021040    0.847826  20.070631               1.0
# 72            0.029996  0.021040    0.720887  24.033032               1.0
# 73            0.029186  0.021040    0.701439  24.033032               1.0
# 75            0.023522  0.021040    0.564399  23.994742               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.026579    2.419798       0.975731  0.466549   0.586742    0.638035
# 1   0.026579    2.902200       0.970892  0.466549   0.655434    0.638035
# 3   0.019799    2.691230       0.958457  0.361974   0.628423    0.548771
# 4   0.021612    2.430729       0.982122  0.473214   0.588601    0.645292
# 5   0.021612    3.086480       0.977300  0.473214   0.676006    0.645292
# 6   0.023581    3.541286       0.977552  0.498922   0.717617    0.670784
# 7   0.023581    2.491813       0.984204  0.498922   0.598686    0.670784
# 8   0.023698    5.575760       0.984471  0.584498   0.820652    0.746520
# 9   0.023698    2.901615       0.991919  0.584498   0.655364    0.746520
# 10  0.016750    1.979422       0.862298  0.185057   0.494802    0.380364
# 12  0.027612    3.114920       0.987771  0.579850   0.678964    0.736928
# 13  0.027612    4.412071       0.982679  0.579850   0.773349    0.736928
# 14  0.019717    1.927594       0.938522  0.300369   0.481219    0.465816
# 16  0.025400    2.448666       0.904819  0.283636   0.591614    0.484058
# 19  0.019289    2.489782       0.895228  0.225000   0.598358    0.445889
# 21  0.017685    1.832001       0.864650  0.198596   0.454149    0.374383
# 22  0.019810    2.079969       0.882927  0.223711   0.519224    0.415987
# 47  0.024725    2.123304       0.922648  0.308373   0.529036    0.483909
# 51  0.020907    1.863100       0.905078  0.259067   0.463260    0.424968
# 53  0.020286    1.971631       0.908604  0.258507   0.492806    0.432114
# 59  0.022343    2.683535       0.954171  0.367863   0.627357    0.553631
# 62  0.022255    4.437611       0.975389  0.482835   0.774654    0.670503
# 63  0.022255    2.188799       0.987861  0.482835   0.543129    0.670503
# 65  0.020652    2.708926       0.873308  0.207289   0.630850    0.450475
# 66  0.018775    1.958731       0.865164  0.203193   0.489465    0.391439
# 68  0.023180    2.053119       0.963645  0.383921   0.512936    0.555656
# 69  0.023180    2.252690       0.960111  0.383921   0.556086    0.555656
# 70  0.020163    9.124923       0.981409  0.529172   0.890410    0.729447
# 71  0.019992    6.293837       0.974356  0.457210   0.841114    0.672955
# 72  0.020165    3.475313       0.987204  0.551627   0.712256    0.711163
# 73  0.020165    3.251641       0.988027  0.551627   0.692463    0.711163
# 75  0.020163    2.241683       0.995433  0.529172   0.553907    0.729447

# %%
strong_rules.sort_values('lift', ascending=False).head(10).plot(
    x='antecedents', y='lift', kind='bar'
)
plt.show()
